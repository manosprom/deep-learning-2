# %% [markdown]
# # Mura Custom CNN

# %%
# %load_ext autoreload
# %autoreload 2

import sys

# sys.path.append("../src")

# %% [markdown]
# # Set seeds for reproducible examples

# %%
from src.seeded import tf

# %% [markdown]
# # Load MURA dataset

# %%
from src.MuraLoader import MuraLoader

muraLoader = MuraLoader()

# %%
from src.models.ModelRunner import ModelRunner
from src.models.builders import custom_cnn_builder

# %%
runner = ModelRunner(muraLoader)

# %% [markdown]
# ## 32 Starting Filters 1 Conv per layers No BatchNorm

# %%
custom_cnn_model = custom_cnn_builder(starting_filters=32, layers=1, convs_per_layer=1, pooling='max')
modelStats = runner.run(name="custom/cnn_32_1_1_max", model=custom_cnn_model, overwrite=False, verbose=0)
display(modelStats.getHistory())
display(modelStats.getEvaluation())
# Out:
#        loss       auc  accuracy     kappa  val_loss   val_auc  val_accuracy  \
# 0  0.688988  0.602682  0.606568  0.098813  0.644162  0.638213      0.618989
# 1  0.576479  0.747783  0.694254  0.327142  0.661251  0.630769      0.622249
# 2  0.425866  0.885742  0.804965  0.581515  0.741427  0.621989      0.616952
# 3  0.292976  0.953178  0.880833  0.748003  0.894801  0.628188      0.619533
# 4  0.200876  0.980861  0.928683  0.850371  1.081503  0.614217      0.615594
# 5  0.136072  0.992433  0.957278  0.910821  1.237117  0.622479      0.613692
# 6  0.077839  0.998648  0.982374  0.963282  1.323709  0.623304      0.612741
# 7  0.064414  0.999171  0.986484  0.971860  1.390928  0.621733      0.611247
# 8  0.055409  0.999424  0.989676  0.978520  1.457345  0.619801      0.614507
#
#    val_kappa      lr
# 0   0.116814  0.0010
# 1   0.167123  0.0010
# 2   0.171948  0.0010
# 3   0.201234  0.0010
# 4   0.176340  0.0010
# 5   0.194828  0.0010
# 6   0.192101  0.0002
# 7   0.185131  0.0002
# ...

# %%
custom_cnn_model = custom_cnn_builder(starting_filters=32, layers=2, convs_per_layer=1, pooling='max')
modelStats = runner.run(name="custom/cnn_32_2_1_max", model=custom_cnn_model, overwrite=False, verbose=0)
display(modelStats.getHistory())
display(modelStats.getEvaluation())
# Out:
#         loss       auc  accuracy     kappa  val_loss   val_auc  val_accuracy  \
# 0   0.667776  0.600191  0.604938  0.082980  0.642728  0.646040      0.622521
# 1   0.621165  0.683143  0.649800  0.220763  0.643402  0.644728      0.632708
# 2   0.555345  0.769666  0.708755  0.369035  0.680986  0.640583      0.617359
# 3   0.444628  0.864295  0.782687  0.536423  0.754438  0.637973      0.622114
# 4   0.318280  0.935741  0.856687  0.697971  0.938337  0.629197      0.620212
# 5   0.212961  0.973457  0.912891  0.817476  1.228827  0.624666      0.620619
# 6   0.115762  0.993979  0.959825  0.916189  1.415493  0.639512      0.627954
# 7   0.089746  0.996504  0.970013  0.937535  1.563104  0.637455      0.628090
# 8   0.072876  0.997890  0.976160  0.950390  1.704736  0.639091      0.629041
# 9   0.058070  0.998743  0.981695  0.961928  1.894355  0.636991      0.629992
# 10  0.045966  0.999321  0.987740  0.974516  2.030909  0.639279      0.628226
# ...

# %%
custom_cnn_model = custom_cnn_builder(starting_filters=32, layers=3, convs_per_layer=1, pooling='max')
modelStats = runner.run(name="custom/cnn_32_3_1_max", model=custom_cnn_model, overwrite=False, verbose=0)
display(modelStats.getHistory())
display(modelStats.getEvaluation())
# Out:
#         loss       auc  accuracy     kappa  val_loss   val_auc  val_accuracy  \
# 0   0.662335  0.590958  0.599776  0.059043  0.646847  0.633258      0.618310
# 1   0.636628  0.653207  0.632921  0.176196  0.637316  0.659169      0.638821
# 2   0.603925  0.707369  0.665999  0.267189  0.616266  0.691874      0.658517
# 3   0.555767  0.767522  0.708347  0.368491  0.636073  0.683176      0.653219
# 4   0.488532  0.831056  0.758269  0.484628  0.664032  0.684007      0.650774
# 5   0.406274  0.889562  0.808259  0.594687  0.784062  0.673193      0.643711
# 6   0.319755  0.933428  0.853427  0.692023  0.959312  0.679856      0.659332
# 7   0.240622  0.963526  0.897813  0.786558  1.156136  0.657314      0.632573
# 8   0.139986  0.989546  0.947259  0.890120  1.351164  0.673049      0.643303
# 9   0.107381  0.994049  0.961998  0.920902  1.550160  0.667166      0.641809
# 10  0.087927  0.996200  0.970047  0.937694  1.701259  0.668249      0.643847
# ...

# %%
custom_cnn_model = custom_cnn_builder(starting_filters=32, layers=4, convs_per_layer=1, pooling='max')
modelStats = runner.run(name="custom/cnn_32_4_1_max", model=custom_cnn_model, overwrite=False, verbose=0)
display(modelStats.getHistory())
display(modelStats.getEvaluation())
# Out:
#         loss       auc  accuracy     kappa  val_loss   val_auc  val_accuracy  \
# 0   0.661354  0.590922  0.602119  0.056034  0.647526  0.638305      0.614371
# 1   0.633500  0.659356  0.634110  0.181484  0.602980  0.707249      0.664357
# 2   0.599530  0.712103  0.670414  0.274261  0.592881  0.725745      0.676175
# 3   0.572746  0.748116  0.697582  0.340144  0.579692  0.738382      0.698180
# 4   0.540975  0.784235  0.725090  0.406327  0.583753  0.731687      0.692882
# 5   0.500072  0.822025  0.753990  0.473956  0.603039  0.737577      0.692747
# 6   0.446619  0.863252  0.787068  0.548461  0.627003  0.736916      0.697772
# 7   0.384734  0.901574  0.825070  0.631486  0.736766  0.719137      0.671285
# 8   0.315982  0.935234  0.859607  0.705920  0.821398  0.729385      0.674545
# 9   0.189857  0.979477  0.925694  0.844890  0.935925  0.727521      0.683374
# 10  0.147039  0.987994  0.945392  0.886245  1.053048  0.724425      0.684325
#
#     val_kappa      lr
# ...

# %%
custom_cnn_model = custom_cnn_builder(starting_filters=32, layers=5, convs_per_layer=1, pooling='max')
modelStats = runner.run(name="custom/cnn_32_5_1_max", model=custom_cnn_model, overwrite=False, verbose=0)
display(modelStats.getHistory())
display(modelStats.getEvaluation())
# Out:
#         loss       auc  accuracy     kappa  val_loss   val_auc  val_accuracy  \
# 0   0.668325  0.558037  0.595463  0.011796  0.657985  0.601475      0.600652
# 1   0.654607  0.605170  0.606228  0.075912  0.636309  0.655758      0.630671
# 2   0.629583  0.663596  0.643992  0.199637  0.603362  0.706091      0.667889
# 3   0.594269  0.715652  0.679141  0.290456  0.579496  0.737245      0.698452
# 4   0.566507  0.753634  0.706140  0.356805  0.580771  0.754781      0.704564
# 5   0.537653  0.786689  0.730524  0.416006  0.588561  0.750345      0.689351
# 6   0.494006  0.825380  0.756266  0.477416  0.582203  0.751721      0.710676
# 7   0.439668  0.867225  0.793996  0.562608  0.619854  0.740835      0.700217
# 8   0.372312  0.907994  0.831488  0.644729  0.643678  0.752184      0.704292
# 9   0.230670  0.969066  0.908205  0.807698  0.782191  0.751643      0.712035
# 10  0.176480  0.981954  0.930483  0.854801  0.878292  0.749530      0.707824
# ...

# %%
#aerrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrr

# %%
custom_cnn_model = custom_cnn_builder(starting_filters=32, layers=1, convs_per_layer=2, pooling='max')
modelStats = runner.run(name="custom/cnn_32_1_2_max", model=custom_cnn_model, overwrite=False, verbose=0)
display(modelStats.getHistory())
display(modelStats.getEvaluation())
# Out:
#         loss       auc  accuracy     kappa  val_loss   val_auc  val_accuracy  \
# 0   0.669309  0.596779  0.603240  0.074334  0.645578  0.636089      0.619669
# 1   0.599538  0.715723  0.672248  0.272684  0.658750  0.650670      0.625102
# 2   0.417919  0.882159  0.800278  0.573047  0.796544  0.631850      0.618718
# 3   0.218471  0.971667  0.909835  0.810498  1.212018  0.607040      0.595626
# 4   0.105236  0.993752  0.963051  0.923011  1.651871  0.617925      0.613284
# 5   0.051384  0.998396  0.985635  0.970118  2.109869  0.610849      0.606900
# 6   0.021288  0.999712  0.995144  0.989912  2.349243  0.619959      0.617495
# 7   0.012050  0.999963  0.997555  0.994921  2.616375  0.620943      0.617088
# 8   0.008224  0.999989  0.998302  0.996473  2.862912  0.618544      0.618718
# 9   0.005535  0.999995  0.999117  0.998166  3.123522  0.617573      0.614779
# 10  0.003458  0.999998  0.999457  0.998872  3.352290  0.618707      0.615458
# ...

# %%
custom_cnn_model = custom_cnn_builder(starting_filters=32, layers=2, convs_per_layer=2, pooling='max')
modelStats = runner.run(name="custom/cnn_32_2_2_max", model=custom_cnn_model, overwrite=False, verbose=0)
display(modelStats.getHistory())
display(modelStats.getEvaluation())
# Out:
#        loss       auc  accuracy     kappa  val_loss   val_auc  val_accuracy  \
# 0  0.661890  0.592924  0.605923  0.086909  0.650625  0.630744      0.615050
# 1  0.631763  0.665259  0.641989  0.197519  0.647432  0.649793      0.634338
# 2  0.586703  0.731291  0.685322  0.310778  0.633675  0.670445      0.651046
# 3  0.500350  0.819719  0.747877  0.458728  0.699957  0.645454      0.627004
# 4  0.369113  0.908852  0.827719  0.636447  0.876746  0.643036      0.626189
# 5  0.239702  0.963104  0.894858  0.780048  1.263325  0.636123      0.623200
# 6  0.152794  0.985022  0.936834  0.868318  1.675584  0.632264      0.614371
# 7  0.096461  0.993726  0.962100  0.921145  2.243781  0.619336      0.618039
#
#    val_kappa     lr
# 0   0.123197  0.001
# 1   0.203251  0.001
# 2   0.237534  0.001
# 3   0.209438  0.001
# 4   0.209195  0.001
# 5   0.210358  0.001
# 6   0.197856  0.001
# 7   0.197087  0.001
#       loss       auc  accuracy     kappa
# 0  0.68841  0.633952  0.603691  0.191749

# %%
custom_cnn_model = custom_cnn_builder(starting_filters=32, layers=3, convs_per_layer=2, pooling='max')
modelStats = runner.run(name="custom/cnn_32_3_2_max", model=custom_cnn_model, overwrite=False, verbose=0)
display(modelStats.getHistory())
display(modelStats.getEvaluation())
# Out:
#         loss       auc  accuracy     kappa  val_loss   val_auc  val_accuracy  \
# 0   0.670119  0.555058  0.594648  0.006928  0.663879  0.590823      0.598479
# 1   0.659408  0.595109  0.602866  0.050526  0.651193  0.632503      0.602554
# 2   0.651778  0.621099  0.614515  0.102985  0.651514  0.626356      0.614507
# 3   0.639788  0.647141  0.627725  0.156031  0.635757  0.661666      0.631894
# 4   0.610370  0.697434  0.663995  0.257688  0.620756  0.682073      0.646292
# 5   0.576541  0.742354  0.692794  0.329382  0.621708  0.691009      0.658653
# 6   0.534744  0.789434  0.723969  0.405821  0.656373  0.679859      0.648058
# 7   0.486437  0.831611  0.757692  0.483634  0.669466  0.690739      0.657023
# 8   0.425164  0.876015  0.795490  0.567158  0.763078  0.673536      0.645341
# 9   0.358593  0.914490  0.834952  0.652815  0.881441  0.673243      0.646156
# 10  0.230294  0.967105  0.901515  0.794135  1.125444  0.674556      0.652404
# ...

# %%
custom_cnn_model = custom_cnn_builder(starting_filters=32, layers=4, convs_per_layer=2, pooling='max')
modelStats = runner.run(name="custom/cnn_32_4_2_max", model=custom_cnn_model, overwrite=False, verbose=0)
display(modelStats.getHistory())
display(modelStats.getEvaluation())
# Out:
#         loss       auc  accuracy     kappa  val_loss   val_auc  val_accuracy  \
# 0   0.674851  0.550334  0.595259  0.001539  0.663166  0.560339      0.595898
# 1   0.667435  0.555885  0.595361  0.002801  0.672731  0.556291      0.597800
# 2   0.670841  0.550671  0.595259  0.014060  0.668998  0.594740      0.589650
# 3   0.659946  0.596662  0.599572  0.045727  0.657148  0.605393      0.602554
# 4   0.652729  0.617568  0.610983  0.095753  0.651271  0.636552      0.621978
# 5   0.644202  0.639256  0.622631  0.144078  0.632389  0.674912      0.640315
# 6   0.633074  0.663444  0.641921  0.198116  0.628024  0.681787      0.646699
# 7   0.618395  0.688190  0.656660  0.241133  0.626307  0.678966      0.662456
# 8   0.599547  0.716968  0.676662  0.292346  0.606453  0.711252      0.668161
# 9   0.581516  0.739054  0.693778  0.334589  0.598409  0.716110      0.686906
# 10  0.558942  0.764628  0.711845  0.378250  0.601596  0.728469      0.683102
# ...

# %%
custom_cnn_model = custom_cnn_builder(starting_filters=32, layers=5, convs_per_layer=2, pooling='max')
modelStats = runner.run(name="custom/cnn_32_5_2_max", model=custom_cnn_model, overwrite=False, verbose=0)
display(modelStats.getHistory())
display(modelStats.getEvaluation())
# Out:
#        loss       auc  accuracy         kappa  val_loss  val_auc  \
# 0  0.676564  0.497929  0.595599 -4.209280e-04  0.674839      0.5
# 1  0.675147  0.502778  0.595938  5.960464e-08  0.675111      0.5
# 2  0.675307  0.495765  0.595938  5.960464e-08  0.675418      0.5
# 3  0.675137  0.497956  0.595938  5.960464e-08  0.674662      0.5
# 4  0.674939  0.502999  0.595938  5.960464e-08  0.674711      0.5
# 5  0.675182  0.494765  0.595938  5.960464e-08  0.674689      0.5
#
#    val_accuracy  val_kappa     lr
# 0      0.595898        0.0  0.001
# 1      0.595898        0.0  0.001
# 2      0.595898        0.0  0.001
# 3      0.595898        0.0  0.001
# 4      0.595898        0.0  0.001
# 5      0.595898        0.0  0.001
#        loss  auc  accuracy  kappa
# 0  0.706796  0.5  0.521426    0.0

# %%
#aerrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrr

# %%
custom_cnn_model = custom_cnn_builder(starting_filters=32, layers=1, convs_per_layer=1, pooling='max', batch_norm=True)
modelStats = runner.run(name="custom/cnn_32_1_1_max_bn", model=custom_cnn_model, overwrite=False, verbose=0)
display(modelStats.getHistory())
display(modelStats.getEvaluation())
# Out:
#        loss       auc  accuracy     kappa  val_loss   val_auc  val_accuracy  \
# 0  0.922153  0.566539  0.595735  0.069485  0.656033  0.620997      0.615458
# 1  0.565347  0.753535  0.696359  0.327358  0.701756  0.605514      0.614643
# 2  0.393601  0.897366  0.813897  0.599532  0.886347  0.586713      0.603097
# 3  0.260644  0.959828  0.889866  0.766333  1.311571  0.579846      0.591551
# 4  0.186833  0.979798  0.926713  0.845605  1.651371  0.581976      0.598207
# 5  0.160300  0.985817  0.943150  0.880695  2.015715  0.578139      0.585303
# 6  0.094538  0.995027  0.966379  0.929674  2.251797  0.583601      0.588835
# 7  0.066689  0.997716  0.975447  0.948732  2.477958  0.586131      0.589921
#
#    val_kappa      lr
# 0   0.119475  0.0010
# 1   0.137168  0.0010
# 2   0.151553  0.0010
# 3   0.134153  0.0010
# 4   0.141387  0.0010
# 5   0.126887  0.0010
# 6   0.134987  0.0002
# 7   0.139913  0.0002
#        loss       auc  accuracy     kappa
# ...

# %%
custom_cnn_model = custom_cnn_builder(starting_filters=32, layers=2, convs_per_layer=1, pooling='max', batch_norm=True)
modelStats = runner.run(name="custom/cnn_32_2_1_max_bn", model=custom_cnn_model, overwrite=False, verbose=0)
display(modelStats.getHistory())
display(modelStats.getEvaluation())
# Out:
#         loss       auc  accuracy     kappa  val_loss   val_auc  val_accuracy  \
# 0   7.002213  0.534160  0.543096  0.053618  9.000669  0.488567      0.448655
# 1   2.697153  0.568884  0.567276  0.100253  1.030136  0.555335      0.577289
# 2   0.809010  0.621291  0.606194  0.162707  0.677051  0.615527      0.606493
# 3   0.636725  0.682929  0.653365  0.249662  0.678365  0.609644      0.610704
# 4   0.582605  0.740023  0.688990  0.326216  0.702770  0.605194      0.611519
# 5   0.541092  0.783993  0.718400  0.393219  0.701574  0.620012      0.619125
# 6   0.486365  0.830821  0.756300  0.479228  0.909337  0.586214      0.598750
# 7   0.429930  0.873152  0.791856  0.558194  0.923559  0.595421      0.596170
# 8   0.301319  0.945809  0.868641  0.722623  1.048713  0.605727      0.608938
# 9   0.256867  0.960897  0.890240  0.769355  1.175516  0.604304      0.607308
# 10  0.223591  0.970887  0.906711  0.804477  1.275895  0.606725      0.606085
# ...

# %%
custom_cnn_model = custom_cnn_builder(starting_filters=32, layers=3, convs_per_layer=1, pooling='max', batch_norm=True)
modelStats = runner.run(name="custom/cnn_32_3_1_max_bn", model=custom_cnn_model, overwrite=False, verbose=0)

# %%
custom_cnn_model = custom_cnn_builder(starting_filters=32, layers=4, convs_per_layer=1, pooling='max', batch_norm=True)
modelStats = runner.run(name="custom/cnn_32_4_1_max_bn", model=custom_cnn_model, overwrite=False, verbose=0)

# %%
custom_cnn_model = custom_cnn_builder(starting_filters=32, layers=5, convs_per_layer=1, pooling='max', batch_norm=True)
modelStats = runner.run(name="custom/cnn_32_5_1_max_bn", model=custom_cnn_model, overwrite=False, verbose=0)

# %%
# 11111111111111111111222223ijoi12j3oi1j3io1j3oi1j3oi1o2j3jo13

# %%
custom_cnn_model = custom_cnn_builder(starting_filters=32, layers=1, convs_per_layer=1, pooling='max', dropout=0.25)
modelStats = runner.run(name="custom/cnn_32_1_1_max_dp", model=custom_cnn_model, overwrite=False, verbose=0)

# %%
custom_cnn_model = custom_cnn_builder(starting_filters=32, layers=2, convs_per_layer=1, pooling='max', dropout=0.25)
modelStats = runner.run(name="custom/cnn_32_2_1_max_dp", model=custom_cnn_model, overwrite=False, verbose=0)

# %%
custom_cnn_model = custom_cnn_builder(starting_filters=32, layers=3, convs_per_layer=1, pooling='max', dropout=0.25)
modelStats = runner.run(name="custom/cnn_32_3_1_max_dp", model=custom_cnn_model, overwrite=False, verbose=0)

# %%
custom_cnn_model = custom_cnn_builder(starting_filters=32, layers=4, convs_per_layer=1, pooling='max', dropout=0.25)
modelStats = runner.run(name="custom/cnn_32_4_1_max_dp", model=custom_cnn_model, overwrite=False, verbose=0)

# %%
custom_cnn_model = custom_cnn_builder(starting_filters=32, layers=5, convs_per_layer=1, pooling='max', dropout=0.25)
modelStats = runner.run(name="custom/cnn_32_5_1_max_dp", model=custom_cnn_model, overwrite=False, verbose=0)

# %%
#33333333333333333333333333333333333333333333333333333333333333333333333333333333333333333333333333333333333333333333333333333

# %%
custom_cnn_model = custom_cnn_builder(starting_filters=32, layers=1, convs_per_layer=1, pooling='max', batch_norm=True, dropout=0.25)
modelStats = runner.run(name="custom/cnn_32_1_1_max_bn_dp", model=custom_cnn_model, overwrite=False, verbose=0)

# %%
custom_cnn_model = custom_cnn_builder(starting_filters=32, layers=2, convs_per_layer=1, pooling='max', batch_norm=True, dropout=0.25)
modelStats = runner.run(name="custom/cnn_32_2_1_max_bn_dp", model=custom_cnn_model, overwrite=False, verbose=0)

# %%
custom_cnn_model = custom_cnn_builder(starting_filters=32, layers=3, convs_per_layer=1, pooling='max', batch_norm=True, dropout=0.25)
modelStats = runner.run(name="custom/cnn_32_3_1_max_bn_dp", model=custom_cnn_model, overwrite=False, verbose=0)

# %%
custom_cnn_model = custom_cnn_builder(starting_filters=32, layers=4, convs_per_layer=1, pooling='max', batch_norm=True, dropout=0.25)
modelStats = runner.run(name="custom/cnn_32_4_1_max_bn_dp", model=custom_cnn_model, overwrite=False, verbose=0)

# %%
custom_cnn_model = custom_cnn_builder(starting_filters=32, layers=5, convs_per_layer=1, pooling='max', batch_norm=True, dropout=0.25)
modelStats = runner.run(name="custom/cnn_32_5_1_max_bn_dp", model=custom_cnn_model, overwrite=False, verbose=0)

# %% [markdown]
# ### More

# %%
custom_cnn_model = custom_cnn_builder(starting_filters=32, layers=5, convs_per_layer=1, pooling='avg', batch_norm=True, dropout=0.25, pool_strides=(2, 2))
modelStats = runner.run(name="tests/custom_cnn_32_5_1_avg_bn_dp", model=custom_cnn_model, overwrite=False, verbose=1)
# Out:
# Saving Model Summary
# Saving Model Plot
# Model: "custom_cnn"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input (InputLayer)           [(None, 256, 256, 3)]     0
# _________________________________________________________________
# conv_0_0 (Conv2D)            (None, 256, 256, 32)      896
# _________________________________________________________________
# bn_0_0 (BatchNormalization)  (None, 256, 256, 32)      128
# _________________________________________________________________
# mp_0 (AveragePooling2D)      (None, 128, 128, 32)      0
# _________________________________________________________________
# dropout_0 (Dropout)          (None, 128, 128, 32)      0
# _________________________________________________________________
# conv_1_0 (Conv2D)            (None, 128, 128, 64)      18496
# _________________________________________________________________
# ...

# %%
custom_cnn_model = custom_cnn_builder(starting_filters=32, layers=5, convs_per_layer=1, pooling='max', batch_norm=True, dropout=0.25, pool_strides=(1, 1), last_pooling="max")
modelStats = runner.run(name="tests/custom_cnn_32_2_1_max_bn_dp_max", model=custom_cnn_model, overwrite=True, verbose=0)

# %%
custom_cnn_model = custom_cnn_builder(starting_filters=32, layers=5, convs_per_layer=1, pooling='avg', batch_norm=True, dropout=0.25, pool_strides=(1, 1), last_pooling="avg")
modelStats = runner.run(name="tests/custom_cnn_32_5_1_avg_bn_dp_avg", model=custom_cnn_model, overwrite=True, verbose=0)
