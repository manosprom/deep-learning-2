# %%
# %load_ext autoreload
# %autoreload 2

import sys

# sys.path.append("../src")

# %% [markdown]
# # Report

# %% [markdown]
# ## Base Model

# %% [markdown]
# ### Base Model 2 CNN layers Training History

# %%
from src.models.ModelRunner import ModelRunner


ModelRunner.plot_histories({
    "model_base":    "custom/cnn_in.256.256.3_cl.2.1_f.32_ck.3.3_p.max_ps.2.2_pstr.2.2",
    "model_bn_norm": "custom/cnn_in.256.256.3_cl.2.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2",
    "model_bn_spdp": "custom/cnn_in.256.256.3_cl.2.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2_spdp.0.25",
    "model_bn_ld":   "custom/cnn_in.256.256.3_cl.2.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2_ld.0.25"
})
# Out:
# model_base custom/cnn_in.256.256.3_cl.2.1_f.32_ck.3.3_p.max_ps.2.2_pstr.2.2
# model_bn_norm custom/cnn_in.256.256.3_cl.2.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2
# model_bn_spdp custom/cnn_in.256.256.3_cl.2.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2_spdp.0.25
# model_bn_ld custom/cnn_in.256.256.3_cl.2.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2_ld.0.25

# %% [markdown]
# ### Base Model best Epochs

# %%
ModelRunner.fetch_best_epochs({
    "model_base":    "custom/cnn_in.256.256.3_cl.2.1_f.32_ck.3.3_p.max_ps.2.2_pstr.2.2",
    "model_bn_norm": "custom/cnn_in.256.256.3_cl.2.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2",
    "model_bn_spdp": "custom/cnn_in.256.256.3_cl.2.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2_spdp.0.25",
    "model_bn_ld":   "custom/cnn_in.256.256.3_cl.2.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2_ld.0.25"
})
# Out:
# model_base custom/cnn_in.256.256.3_cl.2.1_f.32_ck.3.3_p.max_ps.2.2_pstr.2.2
# model_bn_norm custom/cnn_in.256.256.3_cl.2.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2
# model_bn_spdp custom/cnn_in.256.256.3_cl.2.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2_spdp.0.25
# model_bn_ld custom/cnn_in.256.256.3_cl.2.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2_ld.0.25
#               epoch                  loss                   auc  \
# model_base      [0]  [0.6640332937240601]  [0.6006818413734436]
# model_bn_norm   [2]  [0.6393173336982727]  [0.6623112559318542]
# model_bn_spdp   [2]  [0.6531590223312378]  [0.6451549530029297]
# model_bn_ld     [2]   [0.627886950969696]  [0.6741585731506348]
#
#                            accuracy                  kappa  \
# model_base     [0.6059906482696533]  [0.08346885442733765]
# model_bn_norm  [0.6398831605911255]   [0.2173094749450684]
# model_bn_spdp  [0.6290497779846191]  [0.18825709819793698]
# model_bn_ld    [0.6468111276626587]  [0.22310250997543332]
#
# ...

# %% [markdown]
# ### Base Model Evaluation

# %%
ModelRunner.fetch_evaluations({
    "model_base":    "custom/cnn_in.256.256.3_cl.2.1_f.32_ck.3.3_p.max_ps.2.2_pstr.2.2",
    "model_bn_norm": "custom/cnn_in.256.256.3_cl.2.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2",
    "model_bn_spdp": "custom/cnn_in.256.256.3_cl.2.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2_spdp.0.25",
    "model_bn_ld":   "custom/cnn_in.256.256.3_cl.2.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2_ld.0.25"
})
# Out:
# model_base custom/cnn_in.256.256.3_cl.2.1_f.32_ck.3.3_p.max_ps.2.2_pstr.2.2
# model_bn_norm custom/cnn_in.256.256.3_cl.2.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2
# model_bn_spdp custom/cnn_in.256.256.3_cl.2.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2_spdp.0.25
# model_bn_ld custom/cnn_in.256.256.3_cl.2.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2_ld.0.25
#                                loss                   auc  \
# model_base     [0.6775717735290527]   [0.620570182800293]
# model_bn_norm  [0.7049543857574463]   [0.616192638874054]
# model_bn_spdp  [0.6792583465576172]  [0.6190308332443237]
# model_bn_ld    [0.6850495338439941]  [0.6327440142631531]
#
#                            accuracy                  kappa
# model_base     [0.5570847392082214]  [0.08920341730117798]
# model_bn_norm  [0.5749139785766602]  [0.13438475131988525]
# model_bn_spdp  [0.5780419111251831]  [0.13408911228179932]
# model_bn_ld    [0.5817954540252686]  [0.14315879344940186]

# %% [markdown]
# ## Models with more layers

# %% [markdown]
# ### Only Batch Normalization

# %%
from src.models.ModelRunner import ModelRunner


ModelRunner.plot_histories({
    "model_2_bn": "custom/cnn_in.256.256.3_cl.2.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2",
    "model_3_bn": "custom/cnn_in.256.256.3_cl.3.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2",
    "model_4_bn": "custom/cnn_in.256.256.3_cl.4.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2",
    "model_5_bn": "custom/cnn_in.256.256.3_cl.5.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2",
    "model_6_bn": "custom/cnn_in.256.256.3_cl.6.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2"
})
# Out:
# model_2_bn custom/cnn_in.256.256.3_cl.2.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2
# model_3_bn custom/cnn_in.256.256.3_cl.3.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2
# model_4_bn custom/cnn_in.256.256.3_cl.4.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2
# model_5_bn custom/cnn_in.256.256.3_cl.5.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2
# model_6_bn custom/cnn_in.256.256.3_cl.6.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2

# %%
ModelRunner.fetch_evaluations({
    "model_2_bn": "custom/cnn_in.256.256.3_cl.2.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2",
    "model_3_bn": "custom/cnn_in.256.256.3_cl.3.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2",
    "model_4_bn": "custom/cnn_in.256.256.3_cl.4.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2",
    "model_5_bn": "custom/cnn_in.256.256.3_cl.5.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2",
    "model_6_bn": "custom/cnn_in.256.256.3_cl.6.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2",
})
# Out:
# model_2_bn custom/cnn_in.256.256.3_cl.2.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2
# model_3_bn custom/cnn_in.256.256.3_cl.3.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2
# model_4_bn custom/cnn_in.256.256.3_cl.4.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2
# model_5_bn custom/cnn_in.256.256.3_cl.5.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2
# model_6_bn custom/cnn_in.256.256.3_cl.6.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2
#                             loss                   auc              accuracy  \
# model_2_bn  [0.7049543857574463]   [0.616192638874054]  [0.5749139785766602]
# model_3_bn  [0.6917610168457031]  [0.6565930843353271]  [0.6074444651603699]
# model_4_bn  [0.6590577960014343]  [0.7173106670379639]  [0.6618704795837402]
# model_5_bn  [0.6036375164985657]  [0.7572230696678162]  [0.6950265765190125]
# model_6_bn  [0.6198435425758362]  [0.7723996043205261]  [0.6893963217735289]
#
#                             kappa
# model_2_bn  [0.13438475131988525]
# model_3_bn  [0.20123803615570068]
# ...

# %% [markdown]
# ### BatchNorm with Spatial Dropout

# %%
from src.models.ModelRunner import ModelRunner


ModelRunner.plot_histories({
    "model_2_bn": "custom/cnn_in.256.256.3_cl.2.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2_spdp.0.25",
    "model_3_bn": "custom/cnn_in.256.256.3_cl.3.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2_spdp.0.25",
    "model_4_bn": "custom/cnn_in.256.256.3_cl.4.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2_spdp.0.25",
    "model_5_bn": "custom/cnn_in.256.256.3_cl.5.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2_spdp.0.25",
#     "model_6_bn": "custom/cnn_in.256.256.3_cl.6.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2_spdp.0.25"
})
# Out:
# model_2_bn custom/cnn_in.256.256.3_cl.2.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2_spdp.0.25
# model_3_bn custom/cnn_in.256.256.3_cl.3.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2_spdp.0.25
# model_4_bn custom/cnn_in.256.256.3_cl.4.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2_spdp.0.25
# model_5_bn custom/cnn_in.256.256.3_cl.5.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2_spdp.0.25

# %%
from src.models.ModelRunner import ModelRunner


ModelRunner.plot_histories({
    "model_6_bn":           "custom/cnn_in.256.256.3_cl.6.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2",
    "model_6_bn_ld":        "custom/cnn_in.256.256.3_cl.6.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2_ld.0.25",
    "model_6_bn_ld_wc":     "custom/cnn_in.256.256.3_cl.6.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2_ld.0.25__wc",
    "model_6_bn_ld_wc_aug": "custom/cnn_in.256.256.3_cl.6.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2_ld.0.25__wc_aug"
})
# Out:
# model_6_bn custom/cnn_in.256.256.3_cl.6.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2
# model_6_bn_ld custom/cnn_in.256.256.3_cl.6.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2_ld.0.25
# model_6_bn_ld_wc custom/cnn_in.256.256.3_cl.6.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2_ld.0.25__wc
# model_6_bn_ld_wc_aug custom/cnn_in.256.256.3_cl.6.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2_ld.0.25__wc_aug

# %% [markdown]
# ## More Layers comparison

# %% [markdown]
# Comparison of the same cnn with stacked layers
#
# Each CNN cell has
# - kernel (3, 3)
# - BatchNormalization
# - Relu Activation
# - Full Connected layer dropout of 0.25
#
# The comparison is for
#
# - 2 stacks
# - 3 stacks
# - 4 stacks
# - 5 stacks
# - 6 stacks

# %% [markdown]
# ### Training History

# %%
from src.models.ModelRunner import ModelRunner


ModelRunner.plot_histories({
    "model_2_layers": "custom/cnn_in.256.256.3_cl.2.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2_ld.0.25__wc",
    "model_3_layers": "custom/cnn_in.256.256.3_cl.3.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2_ld.0.25__wc",
    "model_4_layers": "custom/cnn_in.256.256.3_cl.4.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2_ld.0.25__wc",
    "model_5_layers": "custom/cnn_in.256.256.3_cl.5.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2_ld.0.25__wc",
    "model_6_layers": "custom/cnn_in.256.256.3_cl.6.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2_ld.0.25__wc"
})
# Out:
# model_2_layers custom/cnn_in.256.256.3_cl.2.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2_ld.0.25__wc
# model_3_layers custom/cnn_in.256.256.3_cl.3.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2_ld.0.25__wc
# model_4_layers custom/cnn_in.256.256.3_cl.4.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2_ld.0.25__wc
# model_5_layers custom/cnn_in.256.256.3_cl.5.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2_ld.0.25__wc
# model_6_layers custom/cnn_in.256.256.3_cl.6.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2_ld.0.25__wc

# %% [markdown]
# ### Best Epochs

# %%
ModelRunner.fetch_best_epochs({
#     "model_2_layers": "custom/cnn_in.256.256.3_cl.2.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2_ld.0.25__wc",
    "model_3_layers": "custom/cnn_in.256.256.3_cl.3.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2_ld.0.25__wc",
    "model_4_layers": "custom/cnn_in.256.256.3_cl.4.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2_ld.0.25__wc",
    "model_5_layers": "custom/cnn_in.256.256.3_cl.5.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2_ld.0.25__wc",
    "model_6_layers": "custom/cnn_in.256.256.3_cl.6.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2_ld.0.25__wc"
})
# Out:
# model_3_layers custom/cnn_in.256.256.3_cl.3.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2_ld.0.25__wc
# model_4_layers custom/cnn_in.256.256.3_cl.4.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2_ld.0.25__wc
# model_5_layers custom/cnn_in.256.256.3_cl.5.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2_ld.0.25__wc
# model_6_layers custom/cnn_in.256.256.3_cl.6.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2_ld.0.25__wc
#                epoch                  loss                   auc  \
# model_3_layers   [7]  [0.5315427184104919]  [0.8076416850090027]
# model_4_layers  [13]  [0.4196323454380035]  [0.8887190818786621]
# model_5_layers  [14]  [0.4224697947502136]  [0.8879661560058594]
# model_6_layers  [17]  [0.4020474553108215]  [0.8979669809341431]
#
#                             accuracy                 kappa  \
# model_3_layers  [0.7280785441398621]  [0.4454463720321655]
# model_4_layers   [0.804625391960144]  [0.5993938446044922]
# model_5_layers  [0.8071045279502869]  [0.6020364761352539]
# ...

# %% [markdown]
# ### Evaluation

# %%
ModelRunner.fetch_evaluations({
#     "model_2_layers": "custom/cnn_in.256.256.3_cl.2.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2_ld.0.25__wc",
    "model_3_layers": "custom/cnn_in.256.256.3_cl.3.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2_ld.0.25__wc",
    "model_4_layers": "custom/cnn_in.256.256.3_cl.4.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2_ld.0.25__wc",
    "model_5_layers": "custom/cnn_in.256.256.3_cl.5.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2_ld.0.25__wc",
    "model_6_layers": "custom/cnn_in.256.256.3_cl.6.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2_ld.0.25__wc"
})
# Out:
# model_3_layers custom/cnn_in.256.256.3_cl.3.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2_ld.0.25__wc
# model_4_layers custom/cnn_in.256.256.3_cl.4.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2_ld.0.25__wc
# model_5_layers custom/cnn_in.256.256.3_cl.5.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2_ld.0.25__wc
# model_6_layers custom/cnn_in.256.256.3_cl.6.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2_ld.0.25__wc
#                                 loss                   auc  \
# model_3_layers  [0.6664800047874451]  [0.6737177968025208]
# model_4_layers   [0.679706871509552]  [0.7067725658416748]
# model_5_layers  [0.5886131525039673]  [0.7787353992462158]
# model_6_layers  [0.5825543403625488]  [0.7931535840034485]
#
#                             accuracy                  kappa
# model_3_layers  [0.6212073564529419]   [0.2394890785217285]
# model_4_layers  [0.6443541049957275]  [0.28576910495758057]
# model_5_layers  [0.7037848234176636]   [0.4037413001060486]
# ...

# %% [markdown]
# ## Augmentation

# %%
from src.models.ModelRunner import ModelRunner


ModelRunner.plot_histories({
    "model_6_layers_base":   "custom/cnn_in.256.256.3_cl.6.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2_ld.0.25",
    "model_6_layers_wc":     "custom/cnn_in.256.256.3_cl.6.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2_ld.0.25__wc",
    "model_6_layers_wc_aug": "custom/cnn_in.256.256.3_cl.6.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2_ld.0.25__wc_aug",
})
# Out:
# model_6_layers_base custom/cnn_in.256.256.3_cl.6.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2_ld.0.25
# model_6_layers_wc custom/cnn_in.256.256.3_cl.6.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2_ld.0.25__wc
# model_6_layers_wc_aug custom/cnn_in.256.256.3_cl.6.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2_ld.0.25__wc_aug

# %% [markdown]
# ### Best Epochs

# %%
ModelRunner.fetch_best_epochs({
    "model_6_layers_base":   "custom/cnn_in.256.256.3_cl.6.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2_ld.0.25",
    "model_6_layers_wc":     "custom/cnn_in.256.256.3_cl.6.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2_ld.0.25__wc",
    "model_6_layers_wc_aug": "custom/cnn_in.256.256.3_cl.6.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2_ld.0.25__wc_aug",
})
# Out:
# model_6_layers_base custom/cnn_in.256.256.3_cl.6.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2_ld.0.25
# model_6_layers_wc custom/cnn_in.256.256.3_cl.6.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2_ld.0.25__wc
# model_6_layers_wc_aug custom/cnn_in.256.256.3_cl.6.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2_ld.0.25__wc_aug
#                       epoch                  loss                   auc  \
# model_6_layers_base    [13]  [0.4815348982810974]  [0.8316164612770081]
# model_6_layers_wc      [17]  [0.4020474553108215]  [0.8979669809341431]
# model_6_layers_wc_aug  [34]  [0.3979619443416596]  [0.8989798426628113]
#
#                                    accuracy                 kappa  \
# model_6_layers_base    [0.7685933709144592]   [0.502282977104187]
# model_6_layers_wc      [0.8173945546150208]  [0.6230074167251587]
# model_6_layers_wc_aug  [0.8210283517837524]  [0.6281633377075195]
#
#                                    val_loss               val_auc  \
# ...

# %% [markdown]
# ### Evaluation

# %%
ModelRunner.fetch_evaluations({
    "model_6_layers_base":   "custom/cnn_in.256.256.3_cl.6.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2_ld.0.25",
    "model_6_layers_wc":     "custom/cnn_in.256.256.3_cl.6.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2_ld.0.25__wc",
    "model_6_layers_wc_aug": "custom/cnn_in.256.256.3_cl.6.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2_ld.0.25__wc_aug",
})
# Out:
# model_6_layers_base custom/cnn_in.256.256.3_cl.6.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2_ld.0.25
# model_6_layers_wc custom/cnn_in.256.256.3_cl.6.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2_ld.0.25__wc
# model_6_layers_wc_aug custom/cnn_in.256.256.3_cl.6.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2_ld.0.25__wc_aug
#                                        loss                   auc  \
# model_6_layers_base    [0.5894367694854736]  [0.7727674245834351]
# model_6_layers_wc      [0.5825543403625488]  [0.7931535840034485]
# model_6_layers_wc_aug  [0.5159420967102051]  [0.8317021131515503]
#
#                                    accuracy                  kappa
# model_6_layers_base    [0.7006568908691406]   [0.3919324278831482]
# model_6_layers_wc      [0.7231779694557191]  [0.44298869371414185]
# model_6_layers_wc_aug  [0.7657178640365601]   [0.5274899601936339]

# %% [markdown]
# ## Different Networks per Body Part

# %% [markdown]
# ### Best Epochs

# %%
ModelRunner.fetch_best_epochs({
    "model_6_layers_ELBOW":    "custom/cnn_in.256.256.3_cl.6.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2_ld.0.25__wc_aug_XR_ELBOW",
    "model_6_layers_FINGER":   "custom/cnn_in.256.256.3_cl.6.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2_ld.0.25__wc_aug_XR_FINGER",
    "model_6_layers_FOREARM":  "custom/cnn_in.256.256.3_cl.6.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2_ld.0.25__wc_aug_XR_FOREARM",
    "model_6_layers_HAND":     "custom/cnn_in.256.256.3_cl.6.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2_ld.0.25__wc_aug_XR_HAND",
    "model_6_layers_HUMERU":   "custom/cnn_in.256.256.3_cl.6.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2_ld.0.25__wc_aug_XR_HUMERUS",
    "model_6_layers_SHOULDER": "custom/cnn_in.256.256.3_cl.6.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2_ld.0.25__wc_aug_XR_SHOULDER",
    "model_6_layers_WRIST":    "custom/cnn_in.256.256.3_cl.6.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2_ld.0.25__wc_aug_XR_WRIST",
})
# Out:
# model_6_layers_ELBOW custom/cnn_in.256.256.3_cl.6.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2_ld.0.25__wc_aug_XR_ELBOW
# model_6_layers_FINGER custom/cnn_in.256.256.3_cl.6.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2_ld.0.25__wc_aug_XR_FINGER
# model_6_layers_FOREARM custom/cnn_in.256.256.3_cl.6.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2_ld.0.25__wc_aug_XR_FOREARM
# model_6_layers_HAND custom/cnn_in.256.256.3_cl.6.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2_ld.0.25__wc_aug_XR_HAND
# model_6_layers_HUMERU custom/cnn_in.256.256.3_cl.6.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2_ld.0.25__wc_aug_XR_HUMERUS
# model_6_layers_SHOULDER custom/cnn_in.256.256.3_cl.6.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2_ld.0.25__wc_aug_XR_SHOULDER
# model_6_layers_WRIST custom/cnn_in.256.256.3_cl.6.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2_ld.0.25__wc_aug_XR_WRIST
#                         epoch                  loss                   auc  \
# model_6_layers_ELBOW      [5]  [1.0459190607070925]  [0.5947659611701965]
# ...

# %% [markdown]
# ### Evaluation

# %%
ModelRunner.fetch_evaluations({
    "model_6_layers_ELBOW":    "custom/cnn_in.256.256.3_cl.6.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2_ld.0.25__wc_aug_XR_ELBOW",
    "model_6_layers_FINGER":   "custom/cnn_in.256.256.3_cl.6.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2_ld.0.25__wc_aug_XR_FINGER",
    "model_6_layers_FOREARM":  "custom/cnn_in.256.256.3_cl.6.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2_ld.0.25__wc_aug_XR_FOREARM",
    "model_6_layers_HAND":     "custom/cnn_in.256.256.3_cl.6.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2_ld.0.25__wc_aug_XR_HAND",
    "model_6_layers_HUMERU":   "custom/cnn_in.256.256.3_cl.6.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2_ld.0.25__wc_aug_XR_HUMERUS",
    "model_6_layers_SHOULDER": "custom/cnn_in.256.256.3_cl.6.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2_ld.0.25__wc_aug_XR_SHOULDER",
    "model_6_layers_WRIST":    "custom/cnn_in.256.256.3_cl.6.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2_ld.0.25__wc_aug_XR_WRIST",
})
# Out:
# model_6_layers_ELBOW custom/cnn_in.256.256.3_cl.6.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2_ld.0.25__wc_aug_XR_ELBOW
# model_6_layers_FINGER custom/cnn_in.256.256.3_cl.6.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2_ld.0.25__wc_aug_XR_FINGER
# model_6_layers_FOREARM custom/cnn_in.256.256.3_cl.6.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2_ld.0.25__wc_aug_XR_FOREARM
# model_6_layers_HAND custom/cnn_in.256.256.3_cl.6.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2_ld.0.25__wc_aug_XR_HAND
# model_6_layers_HUMERU custom/cnn_in.256.256.3_cl.6.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2_ld.0.25__wc_aug_XR_HUMERUS
# model_6_layers_SHOULDER custom/cnn_in.256.256.3_cl.6.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2_ld.0.25__wc_aug_XR_SHOULDER
# model_6_layers_WRIST custom/cnn_in.256.256.3_cl.6.1_f.32_ck.3.3_bn_p.max_ps.2.2_pstr.2.2_ld.0.25__wc_aug_XR_WRIST
#                                          loss                   auc  \
# model_6_layers_ELBOW     [0.7999578714370728]  [0.6142922639846802]
# ...

# %% [markdown]
# # DenseNet

# %%
ModelRunner.plot_histories({
    "densenet_default":             "densenet201/densenet201_in.256.256.3_p.avg__wc_aug",
    "densenet_trainable_after_690": "densenet201/densenet201_in.256.256.3_p.avg_tla.690__wc_aug",
    "densenet_trainable_after_606": "densenet201/densenet201_in.256.256.3_p.avg_tla.606__wc_aug",
    "densenet_trainable_after_606_mlp": "densenet201/densenet201_in.256.256.3_p.avg_tla.606_m.512.512_mdp.0.25__wc_aug",
})
# Out:
# densenet_default densenet201/densenet201_in.256.256.3_p.avg__wc_aug
# densenet_trainable_after_690 densenet201/densenet201_in.256.256.3_p.avg_tla.690__wc_aug
# densenet_trainable_after_606 densenet201/densenet201_in.256.256.3_p.avg_tla.606__wc_aug
# densenet_trainable_after_606_mlp densenet201/densenet201_in.256.256.3_p.avg_tla.606_m.512.512_mdp.0.25__wc_aug

# %%
ModelRunner.fetch_best_epochs({
    "densenet_default":             "densenet201/densenet201_in.256.256.3_p.avg__wc_aug",
    "densenet_trainable_after_690": "densenet201/densenet201_in.256.256.3_p.avg_tla.690__wc_aug",
    "densenet_trainable_after_606": "densenet201/densenet201_in.256.256.3_p.avg_tla.606__wc_aug",
    "densenet_trainable_after_606_mlp": "densenet201/densenet201_in.256.256.3_p.avg_tla.606_m.512.512_mdp.0.25__wc_aug",
})
# Out:
# densenet_default densenet201/densenet201_in.256.256.3_p.avg__wc_aug
# densenet_trainable_after_690 densenet201/densenet201_in.256.256.3_p.avg_tla.690__wc_aug
# densenet_trainable_after_606 densenet201/densenet201_in.256.256.3_p.avg_tla.606__wc_aug
# densenet_trainable_after_606_mlp densenet201/densenet201_in.256.256.3_p.avg_tla.606_m.512.512_mdp.0.25__wc_aug
#                                  epoch                  loss  \
# densenet_default                  [14]  [0.5528280735015869]
# densenet_trainable_after_690      [12]  [0.4507141411304474]
# densenet_trainable_after_606      [14]  [0.3850914239883423]
# densenet_trainable_after_606_mlp  [15]  [0.3973292112350464]
#
#                                                    auc              accuracy  \
# densenet_default                   [0.788080096244812]  [0.7163282036781311]
# densenet_trainable_after_690      [0.8673561811447144]  [0.7971880435943604]
# ...

# %%
ModelRunner.fetch_evaluations({
    "densenet_default":             "densenet201/densenet201_in.256.256.3_p.avg__wc_aug",
    "densenet_trainable_after_690": "densenet201/densenet201_in.256.256.3_p.avg_tla.690__wc_aug",
    "densenet_trainable_after_606": "densenet201/densenet201_in.256.256.3_p.avg_tla.606__wc_aug",
    "densenet_trainable_after_606_mlp": "densenet201/densenet201_in.256.256.3_p.avg_tla.606_m.512.512_mdp.0.25__wc_aug",
})
# Out:
# densenet_default densenet201/densenet201_in.256.256.3_p.avg__wc_aug
# densenet_trainable_after_690 densenet201/densenet201_in.256.256.3_p.avg_tla.690__wc_aug
# densenet_trainable_after_606 densenet201/densenet201_in.256.256.3_p.avg_tla.606__wc_aug
# densenet_trainable_after_606_mlp densenet201/densenet201_in.256.256.3_p.avg_tla.606_m.512.512_mdp.0.25__wc_aug
#                                                    loss                   auc  \
# densenet_default                   [0.5565700531005859]  [0.7884572148323059]
# densenet_trainable_after_690       [0.4704350531101227]  [0.8547149300575256]
# densenet_trainable_after_606      [0.48848319053649897]  [0.8556095957756042]
# densenet_trainable_after_606_mlp   [0.4570291638374329]  [0.8596268892288208]
#
#                                               accuracy                 kappa
# densenet_default                  [0.7228651642799377]  [0.4397755861282349]
# ...
